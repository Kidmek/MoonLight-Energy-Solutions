# %%
import sys
import os
import importlib

# Add the root directory to the system path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from scripts import analysis,visualization,data_loading,data_cleaning

importlib.reload(visualization) # Reload the visualization module (in case it has been changed, 
importlib.reload(data_loading) # Reload the data_loading module (in case it has been changed, 
importlib.reload(data_cleaning) # Reload the data_cleaning module (in case it has been changed, 
importlib.reload(analysis) # Reload the analysis module (in case it has been changed,
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       6 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
#       8 from scripts import analysis,visualization,data_loading,data_cleaning
# ---> 10 importlib.reload(visualization, analysis, data_loading, data_cleaning)
#
# TypeError: reload() takes 1 positional argument but 4 were given

# %%
# Loading in data
data = data_loading.load_data()

# %%
# Summary Statistics
summary_stats = analysis.summary_statistics(data)
display(summary_stats)

# %%
# Data quality check
data_check_result = analysis.data_quality_check(data)
display(data_check_result)

# %%
# Plot time series
visualization.plot_time_series(data, ['GHI', 'DNI', 'DHI', 'Tamb'])

# %%
# Correlation analysis
visualization.correlation_analysis(data)

# %%
# Wind analysis
visualization.wind_analysis(data)

# %%
# Temperature analysis
visualization.temp_analysis(data)

# %%
# Histogram
visualization.histogram(data)

# %%
#Z-Score analysis
data_with_z_score= analysis.z_score_analysis(data)
display(data_with_z_score)

# %%
# Bubble charts
visualization.bubble_chart(data, 'GHI', 'Tamb', 'RH', 'BP')

# %%
# Data cleaning
data_cleaning.clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Data cleaning
# ----> 2 data_cleaning.clean_data()
#
# TypeError: clean_data() missing 1 required positional argument: 'data'
